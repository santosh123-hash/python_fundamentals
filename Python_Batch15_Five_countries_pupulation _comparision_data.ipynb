# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
#1.Comparing US and Slovenia countries data

# %%
US = data[data.country == 'United States']
US
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
Slovenia = data[data.country == 'Slovenia']
Slovenia
# Out:
#        country  year  population
# 1380  Slovenia  1952     1489518
# 1381  Slovenia  1957     1533070
# 1382  Slovenia  1962     1582962
# 1383  Slovenia  1967     1646912
# 1384  Slovenia  1972     1694510
# 1385  Slovenia  1977     1746919
# 1386  Slovenia  1982     1861252
# 1387  Slovenia  1987     1945870
# 1388  Slovenia  1992     1999210
# 1389  Slovenia  1997     2011612
# 1390  Slovenia  2002     2011497
# 1391  Slovenia  2007     2009245

# %%
plt.plot(US.year, US.population)
plt.plot(Slovenia.year, Slovenia.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparion')
plt.legend(['United States', 'Slovenia'])
plt.show()

# %%
#2.Comparing Afghanistan and Albania countries data

# %%
Afghan = data[data.country == 'Afghanistan']
Afghan
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
Albania = data[data.country == 'Albania']
Albania
# Out:
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523

# %%
plt.plot(Afghan.year, Afghan.population)
plt.plot(Albania.year, Albania.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparion')
plt.legend(['Afghan', 'Albania'])
plt.show()

# %%
#3. Comparing Argentina and Australia Population data

# %%
Argentina = data[data.country == 'Argentina']
Argentina
# Out:
#       country  year  population
# 48  Argentina  1952    17876956
# 49  Argentina  1957    19610538
# 50  Argentina  1962    21283783
# 51  Argentina  1967    22934225
# 52  Argentina  1972    24779799
# 53  Argentina  1977    26983828
# 54  Argentina  1982    29341374
# 55  Argentina  1987    31620918
# 56  Argentina  1992    33958947
# 57  Argentina  1997    36203463
# 58  Argentina  2002    38331121
# 59  Argentina  2007    40301927

# %%
Australia = data[data.country == 'Australia']
Australia
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
plt.plot(Argentina.year, Argentina.population)
plt.plot(Australia.year, Australia.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparion')
plt.legend(['Argentina', 'Australia'])
plt.show()

# %%
#4.  Comparing France and Italy data

# %%
France = data[data.country == 'France']
France
# Out:
#     country  year  population
# 528  France  1952    42459667
# 529  France  1957    44310863
# 530  France  1962    47124000
# 531  France  1967    49569000
# 532  France  1972    51732000
# 533  France  1977    53165019
# 534  France  1982    54433565
# 535  France  1987    55630100
# 536  France  1992    57374179
# 537  France  1997    58623428
# 538  France  2002    59925035
# 539  France  2007    61083916

# %%
Italy = data[data.country == 'Italy']
Italy
# Out:
#     country  year  population
# 768   Italy  1952    47666000
# 769   Italy  1957    49182000
# 770   Italy  1962    50843200
# 771   Italy  1967    52667100
# 772   Italy  1972    54365564
# 773   Italy  1977    56059245
# 774   Italy  1982    56535636
# 775   Italy  1987    56729703
# 776   Italy  1992    56840847
# 777   Italy  1997    57479469
# 778   Italy  2002    57926999
# 779   Italy  2007    58147733

# %%
plt.plot(France.year, France.population)
plt.plot(Italy.year, Italy.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparion')
plt.legend(['France', 'Italy'])
plt.show()

# %%
#5. Comparing Netherlands and  New Zealand data

# %%
Netherland = data[data.country == 'Netherlands']
Netherland
# Out:
#           country  year  population
# 1080  Netherlands  1952    10381988
# 1081  Netherlands  1957    11026383
# 1082  Netherlands  1962    11805689
# 1083  Netherlands  1967    12596822
# 1084  Netherlands  1972    13329874
# 1085  Netherlands  1977    13852989
# 1086  Netherlands  1982    14310401
# 1087  Netherlands  1987    14665278
# 1088  Netherlands  1992    15174244
# 1089  Netherlands  1997    15604464
# 1090  Netherlands  2002    16122830
# 1091  Netherlands  2007    16570613

# %%
New_Zealand = data[data.country == 'New Zealand']
New_Zealand
# Out:
#           country  year  population
# 1092  New Zealand  1952     1994794
# 1093  New Zealand  1957     2229407
# 1094  New Zealand  1962     2488550
# 1095  New Zealand  1967     2728150
# 1096  New Zealand  1972     2929100
# 1097  New Zealand  1977     3164900
# 1098  New Zealand  1982     3210650
# 1099  New Zealand  1987     3317166
# 1100  New Zealand  1992     3437674
# 1101  New Zealand  1997     3676187
# 1102  New Zealand  2002     3908037
# 1103  New Zealand  2007     4115771

# %%
plt.plot(Netherland.year, Netherland.population)
plt.plot(New_Zealand.year, New_Zealand.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparion')
plt.legend(['Netherland', 'New_Zealand'])
plt.show()
